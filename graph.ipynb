# %%
import pandas as pd

xs = [int(x.strip()) for x in open('frags.csv').readlines()]
xs
# Out:
# [1,
#  5,
#  5,
#  2,
#  -8,
#  27,
#  5,
#  -1,
#  7,
#  4,
#  1,
#  1,
#  9,
#  6,
#  -2,
#  4,
#  1,
#  -2,
#  5,
#  0,
#  1,
#  4,
#  0,
#  2,
#  -10,
#  2,
#  2,
#  0,
#  0,
#  4,
#  0,
#  3,
#  7,
#  -3,
#  1,
#  -23,
#  7,
#  1,
#  -4,
#  9,
#  3,
#  1,
#  4,
#  -1,
#  2,
#  1,
#  1,
#  -6,
#  1,
#  1,
#  1,
#  -7,
#  0,
#  1,
#  -2,
#  2,
#  -2,
#  1,
#  2,
#  1,
#  6,
#  3,
#  2,
#  -11,
#  0,
#  3,
#  0,
#  2,
#  -6,
#  1,
#  3,
#  -14,
#  4,
#  6,
#  -1,
#  -2,
#  8,
#  0,
#  -8,
#  2,
#  0,
#  0,
#  0,
#  1,
#  1,
#  0,
#  1,
#  0,
#  1,
#  1,
#  1,
#  2,
#  1,
#  -1,
#  0,
#  0,
#  1,
#  7,
#  6,
#  -1,
#  2,
#  1,
#  2,
#  1,
#  1,
#  0,
#  1,
#  1,
#  1,
#  0,
#  1,
#  16,
#  0,
#  1,
#  1,
#  3,
#  2,
#  0,
#  -3,
#  3,
#  19,
#  -26,
#  7,
#  3,
#  4,
#  12,
#  1,
#  2,
#  1,
#  1,
#  25,
#  -9,
#  5,
#  1,
#  -21,
#  1,
#  6,
#  0,
#  1,
#  1,
#  36,
#  0,
#  11,
#  -6,
#  0,
#  4,
#  1,
#  18,
#  9,
#  -35,
#  2,
#  10,
#  26,
#  1,
#  1,
#  2,
#  0,
#  5,
#  5,
# ...

# %%
from matplotlib import pyplot as plt
plt.hist(xs, bins=100)
# Out:
# (array([1.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#         0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 1.000e+00, 0.000e+00,
#         0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 4.000e+00,
#         2.000e+00, 0.000e+00, 4.000e+00, 2.000e+00, 1.000e+00, 4.000e+00,
#         0.000e+00, 7.000e+00, 8.000e+00, 5.000e+00, 1.400e+01, 1.700e+01,
#         1.200e+01, 1.600e+01, 3.400e+01, 2.600e+01, 6.500e+01, 9.600e+01,
#         6.100e+01, 1.610e+02, 1.160e+02, 3.320e+02, 4.980e+02, 3.700e+02,
#         2.225e+03, 1.580e+03, 6.040e+02, 8.280e+02, 5.320e+02, 2.230e+02,
#         3.720e+02, 1.340e+02, 2.440e+02, 1.650e+02, 9.000e+01, 1.370e+02,
#         1.240e+02, 4.400e+01, 9.500e+01, 6.700e+01, 2.800e+01, 4.700e+01,
#         3.800e+01, 1.300e+01, 3.400e+01, 1.600e+01, 2.400e+01, 1.100e+01,
#         6.000e+00, 1.700e+01, 1.700e+01, 3.000e+00, 1.100e+01, 5.000e+00,
#         0.000e+00, 7.000e+00, 3.000e+00, 1.000e+00, 4.000e+00, 3.000e+00,
# ...
